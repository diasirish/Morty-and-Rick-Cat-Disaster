# %%
import pandas
import numpy


x = 360000
i_rate = 0.3

# %%
# strategy 1
total_return_1 = ((x*i_rate)*0.2*0.5)*3

# strategy 2
total_return_2 = ((x*i_rate)*0.2*0.3 + x*0.01)*3

# strategy 3
total_return_3 = (x*i_rate)*0.2*0.1 + x*0.015*0.1

print(total_return_1, total_return_2, total_return_3)
# Out:
# 32400.0 30240.0 2700.0

# %%
commission_rate = 0.02
average_home_cost = 400000
ammount_to_sell = 0
total_return = 0

while total_return < 300000:
    ammount_to_sell += 1
    total_return = average_home_cost * commission_rate * ammount_to_sell
total_return, ammount_to_sell
# Out:
# (304000.0, 38)

# %%
# So to gain 300'000 I need to attract $3'600'000  to fond or
# sell 38 houses
